# %% [markdown]
# # Collecting Data from Amazon
# ---
# In this notebook, we scrape the missing parts of our dataset directly from Amazon using BeautifulSoup.
#
# The dataset we want:
#
# | ID | Review Score | Sales Rank | Category    | Title | Author | Date    | Visual Features     |
# | -- | ------------ | ---------- | ----------- | ----- | ------ | ------- | ------------------- |
# | |
#
# The dataset we have, as downloaded from [here](https://github.com/uchidalab/book-dataset):
#
# | ID | Filename | Image URL | Title | Author | Category ID | Category |
# | -- | -------- | --------- | ----- | ------ | ----------- | -------- |
# | |
#
# The `ID` column in the data can be used to access the webpage of each book, by connecting to https://www.amazon.com/dp/book-id. This allows us to scrape any data that is missing directly from Amazon.
#
# We already have the Title, Author and Category of each book ready to be used.
#
# For everything else, there's ~~Mastercard~~ BeautifulSoup.

# %%
import requests
from bs4 import BeautifulSoup

import pandas as pd
import re
from datetime import datetime
from time import sleep
from random import randint
import csv
import urllib
import os

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# Load the data:

# %%
header_names = ['ID', 'Filename', 'Image URL', 'Title', 'Author', 'Category ID', 'Category']

books = pd.read_csv('book32-listing.csv', encoding='latin1', header=None, names=header_names)
books.head()
# Out:
#            ID        Filename  \
# 0   761183272  0761183272.jpg
# 1  1623439671  1623439671.jpg
# 2  B00O80WC6I  B00O80WC6I.jpg
# 3   761182187  0761182187.jpg
# 4  1578052084  1578052084.jpg
#
#                                            Image URL  \
# 0  http://ecx.images-amazon.com/images/I/61Y5cOdH...
# 1  http://ecx.images-amazon.com/images/I/61t-hrSw...
# 2  http://ecx.images-amazon.com/images/I/41X-KQqs...
# 3  http://ecx.images-amazon.com/images/I/61j-4gxJ...
# 4  http://ecx.images-amazon.com/images/I/51Ry4Tsq...
#
#                                                Title              Author  \
# 0                    Mom's Family Wall Calendar 2016      Sandra Boynton
# 1                    Doug the Pug 2016 Wall Calendar        Doug the Pug
# 2  Moleskine 2016 Weekly Notebook, 12M, Large, Bl...           Moleskine
# 3            365 Cats Color Page-A-Day Calendar 2016  Workman Publishing
# 4               Sierra Club Engagement Calendar 2016         Sierra Club
#
#    Category ID   Category
# 0            3  Calendars
# 1            3  Calendars
# 2            3  Calendars
# 3            3  Calendars
# 4            3  Calendars

# %% [markdown]
# Inspect the categories:

# %%
print('\n'.join(books['Category'].unique()))
# Out:
# Calendars
# Comics & Graphic Novels
# Test Preparation
# Mystery, Thriller & Suspense
# Science Fiction & Fantasy
# Romance
# Humor & Entertainment
# Literature & Fiction
# Gay & Lesbian
# Engineering & Transportation
# Cookbooks, Food & Wine
# Crafts, Hobbies & Home
# Arts & Photography
# Education & Teaching
# Parenting & Relationships
# Self-Help
# Computers & Technology
# Medical Books
# Science & Math
# Health, Fitness & Dieting
# Business & Money
# Law
# Biographies & Memoirs
# History
# Politics & Social Sciences
# Reference
# Christian Books & Bibles
# Religion & Spirituality
# Sports & Outdoors
# Teen & Young Adult
# Children's Books
# Travel

# %% [markdown]
# We only want the Children's Books and we don't need the Category ID:

# %%
books = books[books['Category'] == "Children's Books"].reset_index(drop=True)
books.drop(columns=['Category ID'], inplace=True)
books.head()
# Out:
#            ID        Filename  \
# 0   545790352  0545790352.jpg
# 1  1419717014  1419717014.jpg
# 2  1423160916  1423160916.jpg
# 3  1476789886  1476789886.jpg
# 4  1338029991  1338029991.jpg
#
#                                            Image URL  \
# 0  http://ecx.images-amazon.com/images/I/51MIi4p2...
# 1  http://ecx.images-amazon.com/images/I/61YgGsg-...
# 2  http://ecx.images-amazon.com/images/I/611CmvkL...
# 3  http://ecx.images-amazon.com/images/I/51KqU7Dw...
# 4  http://ecx.images-amazon.com/images/I/61kvq74k...
#
#                                                Title         Author  \
# 0  Harry Potter and the Sorcerer's Stone: The Ill...   J.K. Rowling
# 1                   Diary of a Wimpy Kid: Old School    Jeff Kinney
# 2  Magnus Chase and the Gods of Asgard, Book 1: T...   Rick Riordan
# 3           Rush Revere and the Star-Spangled Banner  Rush Limbaugh
# 4                         Harry Potter Coloring Book     Scholastic
#
#            Category
# 0  Children's Books
# 1  Children's Books
# 2  Children's Books
# 3  Children's Books
# 4  Children's Books

# %% [markdown]
# Let's check how many books we have left:

# %%
len(books)
# Out:
# 13605

# %% [markdown]
# We are going to lose quite a bit more because some of them will not be on sale on Amazon anymore, so we will not be able to scrape information on them.

# %% [markdown]
# ## Scraping

# %% [markdown]
# The columns we need to scrape are: `Review Score`, `Sales Rank` and `Date`. We also need to download the images from the URLs so that we can extract visual features from them, completing our dataset.
#
# First we will demonstrate the scraping process for each column on an arbitrary example, then we will combine these in a function and scrape the information for all the books.

# %%
# Arbitrary book
book_id = '1419717014'
books[books['ID'] == book_id]
# Out:
#            ID        Filename  \
# 1  1419717014  1419717014.jpg
#
#                                            Image URL  \
# 1  http://ecx.images-amazon.com/images/I/61YgGsg-...
#
#                               Title       Author          Category
# 1  Diary of a Wimpy Kid: Old School  Jeff Kinney  Children's Books

# %%
request = requests.get('https://www.amazon.com/dp/' + book_id)
soup = BeautifulSoup(request.text, 'lxml')

# %% [markdown]
# #### Sales Rank and Date

# %% [markdown]
# We can get both of these from the product details table on the webpage, which is in a table conveniently named `productDetailsTable`:

# %%
soup.select('#productDetailsTable li b')
# Out:
# [<b>Age Range:</b>,
#  <b>Grade Level:</b>,
#  <b>Lexile Measure:</b>,
#  <b>Series:</b>,
#  <b>Hardcover:</b>,
#  <b>Publisher:</b>,
#  <b>Language:</b>,
#  <b>ISBN-10:</b>,
#  <b>ISBN-13:</b>,
#  <b>
#      Product Dimensions:
#      </b>,
#  <b>Shipping Weight:</b>,
#  <b>Average Customer Review:</b>,
#  <b>Amazon Best Sellers Rank:</b>,
#  <b><a href="https://www.amazon.com/gp/bestsellers/books/2909">Computers &amp; Technology</a></b>,
#  <b><a href="https://www.amazon.com/gp/bestsellers/books/15356791">School</a></b>,
#  <b><a href="https://www.amazon.com/gp/bestsellers/books/3014">Comics &amp; Graphic Novels</a></b>]

# %% [markdown]
# Again, we can use regex to extract the info we need from the table:

# %%
for li in soup.select('#productDetailsTable li'):
    # We only need two of the list items
    if(li.b.string == 'Amazon Best Sellers Rank:'):
        # The rank is given in the format #1,234,567
        sales_rank = re.findall(u'#([\d,]+)', li.b.nextSibling)[0]
    elif(li.b.string == 'Publisher:'):
        # The date is in parantheses and in the format (MM YYYY)
        date = re.findall(u'\(([^\(\)]*)\)$', li.b.nextSibling)[0]
        
print(f'Sales Rank: {sales_rank}\nDate: {date}')
# Out:
# Sales Rank: 383
# Date: November 3, 2015

# %% [markdown]
# #### Review Score

# %% [markdown]
# You might have noticed there is also an item called `Average Customer Review` in the table we just used to extract the Rank and Date. Inside that item, all the review scores are found in a table with the id `histogramTable`, that gives the percentages of users for each score from 1 to 5 stars.

# %%
reviews = soup.select('#histogramTable')[0].text
reviews
# Out:
# '5 star88%4 star7%3 star3%2 star1%1 star1%'

# %% [markdown]
# The formatting is not great, but it's nothing we can't fix by using a simple regular expression:

# %%
reviews = re.findall(u'(\d) star(\d+)%', reviews)
reviews
# Out:
# [('5', '88'), ('4', '7'), ('3', '3'), ('2', '1'), ('1', '1')]

# %% [markdown]
# The weighted average of these scores is our final Review Score for the given book:

# %%
score = 0
for pair in reviews:
    score += int(pair[0]) * int(pair[1])/100  # weights are percentages

score
# Out:
# 4.8

# %% [markdown]
# #### Cover Image

# %% [markdown]
# The image URL of each book is available in the original dataset, let's make a HashMap of `ID:URL` pairs:

# %%
urls = books[['ID', 'Image URL']].set_index('ID').to_dict()['Image URL']
urls[book_id]
# Out:
# 'http://ecx.images-amazon.com/images/I/61YgGsg-k-L.jpg'

# %% [markdown]
# Let's have a look:
#
# ![Example Image](http://ecx.images-amazon.com/images/I/61YgGsg-k-L.jpg)

# %% [markdown]
# Seems correct, let's turn it into a function:

# %%
def download_image(book_id):
    url = urls[book_id]
    # Download only if not already downloaded
    if not os.path.isfile(IMAGE_PATH + filename):
            downloaded_img = urllib.request.urlopen(url)
            f = open(IMAGE_PATH + book_id + '.jpg', mode='wb')
            f.write(downloaded_img.read())
            downloaded_img.close()
            f.close()

# %%
books
# Out:
#                ID        Filename  \
# 0       545790352  0545790352.jpg
# 1      1419717014  1419717014.jpg
# 2      1423160916  1423160916.jpg
# 3      1476789886  1476789886.jpg
# 4      1338029991  1338029991.jpg
# 5       399172750  0399172750.jpg
# 6       399255370  0399255370.jpg
# 7       545392551  0545392551.jpg
# 8       399226907  0399226907.jpg
# 9      1481457047  1481457047.jpg
# 10       62304186  0062304186.jpg
# 11     141694737X  141694737X.jpg
# 12      803741715  0803741715.jpg
# 13      544568036  0544568036.jpg
# 14      385376715  0385376715.jpg
# 15       60256656  0060256656.jpg
# 16      756634687  0756634687.jpg
# 17      553512331  0553512331.jpg
# 18      920668372  0920668372.jpg
# 19      142501123  0142501123.jpg
# 20      553522779  0553522779.jpg
# 21     1484707230  1484707230.jpg
# 22      805047905  0805047905.jpg
# 23      800788036  0800788036.jpg
# 24      803736800  0803736800.jpg
# 25      694003611  0694003611.jpg
# 26      671449028  0671449028.jpg
# 27     1442450703  1442450703.jpg
# 28      763644765  0763644765.jpg
# 29      679805273  0679805273.jpg
# ...           ...             ...
# 13575   525474560  0525474560.jpg
# 13576  1423100832  1423100832.jpg
# 13577   316796433  0316796433.jpg
# 13578  1434227839  1434227839.jpg
# 13579  1681890046  1681890046.jpg
# 13580  155028679X  155028679X.jpg
# 13581  1434296687  1434296687.jpg
# 13582   448453436  0448453436.jpg
# 13583   807554138  0807554138.jpg
# 13584   763679585  0763679585.jpg
# 13585  1552775674  1552775674.jpg
# 13586  1554693926  1554693926.jpg
# 13587   771056281  0771056281.jpg
# 13588   822517957  0822517957.jpg
# 13589   316135127  0316135127.jpg
# 13590  1434227987  1434227987.jpg
# 13591   316142697  0316142697.jpg
# 13592  1934649376  1934649376.jpg
# 13593   988636905  0988636905.jpg
# 13594   805044558  0805044558.jpg
# 13595   811817156  0811817156.jpg
# 13596  1550288229  1550288229.jpg
# 13597  077105629X  077105629X.jpg
# 13598   771056443  0771056443.jpg
# 13599  1582463298  1582463298.jpg
# 13600  1550288563  1550288563.jpg
# 13601  143422306X  143422306X.jpg
# 13602   399243232  0399243232.jpg
# 13603  1467757810  1467757810.jpg
# 13604  1553373677  1553373677.jpg
#
#                                                Image URL  \
# 0      http://ecx.images-amazon.com/images/I/51MIi4p2...
# 1      http://ecx.images-amazon.com/images/I/61YgGsg-...
# 2      http://ecx.images-amazon.com/images/I/611CmvkL...
# 3      http://ecx.images-amazon.com/images/I/51KqU7Dw...
# 4      http://ecx.images-amazon.com/images/I/61kvq74k...
# 5      http://ecx.images-amazon.com/images/I/51ZnaboA...
# 6      http://ecx.images-amazon.com/images/I/51HoHYJv...
# 7      http://ecx.images-amazon.com/images/I/51qvh4MA...
# 8      http://ecx.images-amazon.com/images/I/41zqrOnj...
# 9      http://ecx.images-amazon.com/images/I/61GfN%2B...
# 10     http://ecx.images-amazon.com/images/I/61OU9ICZ...
# 11     http://ecx.images-amazon.com/images/I/51SQFs%2...
# 12     http://ecx.images-amazon.com/images/I/4148uGcg...
# 13     http://ecx.images-amazon.com/images/I/51xF%2B0...
# 14     http://ecx.images-amazon.com/images/I/51q3%2Bu...
# 15     http://ecx.images-amazon.com/images/I/51-k2MEd...
# 16     http://ecx.images-amazon.com/images/I/51SIi1Rk...
# 17     http://ecx.images-amazon.com/images/I/51AeOMhY...
# 18     http://ecx.images-amazon.com/images/I/612wpFrT...
# 19     http://ecx.images-amazon.com/images/I/61S45JlZ...
# 20     http://ecx.images-amazon.com/images/I/61FiwrNC...
# 21     http://ecx.images-amazon.com/images/I/41FsJLoz...
# 22     http://ecx.images-amazon.com/images/I/51XqfNJb...
# 23     http://ecx.images-amazon.com/images/I/51I-yiY4...
# 24     http://ecx.images-amazon.com/images/I/61P9zL-N...
# 25     http://ecx.images-amazon.com/images/I/51%2BmV1...
# 26     http://ecx.images-amazon.com/images/I/61TU%2B6...
# 27     http://ecx.images-amazon.com/images/I/51HsU2QL...
# 28     http://ecx.images-amazon.com/images/I/51GGQuVi...
# 29     http://ecx.images-amazon.com/images/I/51Fnoqj1...
# ...                                                  ...
# 13575  http://ecx.images-amazon.com/images/I/51BXFxl6...
# 13576  http://ecx.images-amazon.com/images/I/51teaDiw...
# 13577  http://ecx.images-amazon.com/images/I/51Ht6T0e...
# 13578  http://ecx.images-amazon.com/images/I/61Tb8Kzv...
# 13579  http://ecx.images-amazon.com/images/I/61Sigu8x...
# 13580  http://ecx.images-amazon.com/images/I/51peHkJS...
# 13581  http://ecx.images-amazon.com/images/I/51YkPxNn...
# 13582  http://ecx.images-amazon.com/images/I/51K50gRZ...
# 13583  http://ecx.images-amazon.com/images/I/51WbrFQy...
# 13584  http://ecx.images-amazon.com/images/I/5111V-HR...
# 13585  http://ecx.images-amazon.com/images/I/41n-kfhn...
# 13586  http://ecx.images-amazon.com/images/I/41Y%2Bw8...
# 13587  http://ecx.images-amazon.com/images/I/51UohkWu...
# 13588  http://ecx.images-amazon.com/images/I/41BWWWG6...
# 13589  http://ecx.images-amazon.com/images/I/51TTcPku...
# 13590  http://ecx.images-amazon.com/images/I/51UlcEp4...
# 13591  http://ecx.images-amazon.com/images/I/51FSsg1%...
# 13592  http://ecx.images-amazon.com/images/I/51bjZTeO...
# 13593  http://ecx.images-amazon.com/images/I/51mkG9y2...
# 13594  http://ecx.images-amazon.com/images/I/5155OWqu...
# 13595  http://ecx.images-amazon.com/images/I/61ocs2Lb...
# 13596  http://ecx.images-amazon.com/images/I/514-JP9D...
# 13597  http://ecx.images-amazon.com/images/I/5193Q0EY...
# 13598  http://ecx.images-amazon.com/images/I/51iqpvY0...
# 13599  http://ecx.images-amazon.com/images/I/51eoC-Pk...
# 13600  http://ecx.images-amazon.com/images/I/51xsKAyI...
# 13601  http://ecx.images-amazon.com/images/I/51LxxMkD...
# 13602  http://ecx.images-amazon.com/images/I/51Ex2XZk...
# 13603  http://ecx.images-amazon.com/images/I/51MAYXG-...
# 13604  http://ecx.images-amazon.com/images/I/51BU3bFi...
#
#                                                    Title  \
# 0      Harry Potter and the Sorcerer's Stone: The Ill...
# 1                       Diary of a Wimpy Kid: Old School
# 2      Magnus Chase and the Gods of Asgard, Book 1: T...
# 3               Rush Revere and the Star-Spangled Banner
# 4                             Harry Potter Coloring Book
# 5                          The Day the Crayons Came Home
# 6                               The Day the Crayons Quit
# 7                                   Giraffes Can't Dance
# 8                            The Very Hungry Caterpillar
# 9      Dork Diaries 10: Tales from a Not-So-Perfect P...
# 10                    Pete the Cat: Five Little Pumpkins
# 11     Dear Zoo: A Lift-the-Flap Book (Dear Zoo & Fri...
# 12                             The Book with No Pictures
# 13                          Little Blue Truck board book
# 14                      The Wonderful Things You Will Be
# 15                                       The Giving Tree
# 16                         Animals (Baby Touch and Feel)
# 17                                         Spooky Pookie
# 18                                      Love You Forever
# 19                                     Room on the Broom
# 20     Puppy Birthday to You! (Paw Patrol) (Little Go...
# 21     Percy Jackson and the Olympians 5 Book Paperba...
# 22              Brown Bear, Brown Bear, What Do You See?
# 23                         Laugh-Out-Loud Jokes for Kids
# 24                                    Dragons Love Tacos
# 25                                        Goodnight Moon
# 26                                 The Going-To-Bed Book
# 27       Chicka Chicka Boom Boom (Chicka Chicka Book, A)
# 28                 Potty (Leslie Patricelli board books)
# 29                             Oh, The Places You'll Go!
# ...                                                  ...
# 13575                                    Snowball Fight!
# 13576                            The Million Dollar Goal
# 13577  Snowboard Champ (Matt Christopher Sports Fiction)
# 13578  Avalanche Freestyle (Sports Illustrated Kids G...
# 13579                                            WHOOSH!
# 13580           Brothers on Ice (Lorimer Sports Stories)
# 13581                    Snowboard Hero (Jake Maddox JV)
# 13582                   Figure Skating (Sticker Stories)
# 13583  The Mystery on the Ice (Boxcar Children Winter...
# 13584                                               Snow
# 13585                  Roughing (Lorimer Sports Stories)
# 13586                             The Drop (Orca Sports)
# 13587  The Screech Owls' Northern Adventure (Screech ...
# 13588          Michelle Kwan (Sports Heroes and Legends)
# 13589  Snowboard Showdown: Out-of Control Competition...
# 13590  Buzz Beaker and the Speed Secret (Buzz Beaker ...
# 13591  Wingman On Ice (Matt Christopher Sports Classics)
# 13592    Hotdogger (The Aldo Zelnick Comic Novel Series)
# 13593                        It's a Day for Ski and Play
# 13594       Emmett's Snowball (Henry Holt Young Readers)
# 13595                               Rhinos Who Snowboard
# 13596              Interference (Lorimer Sports Stories)
# 13597     Murder at Hockey Camp (Screech Owls Series #4)
# 13598         Death Down Under (Screech Owls Series #15)
# 13599                                        Snow Happy!
# 13600                   Play On (Lorimer Sports Stories)
# 13601              Snorp on the Slopes (Monster Friends)
# 13602                                   Painter and Ugly
# 13603                Mikaela Shiffrin (Amazing Athletes)
# 13604                    Snowy Sports: Ready, Set, Play!
#
#                         Author          Category
# 0                 J.K. Rowling  Children's Books
# 1                  Jeff Kinney  Children's Books
# 2                 Rick Riordan  Children's Books
# 3                Rush Limbaugh  Children's Books
# 4                   Scholastic  Children's Books
# 5                 Drew Daywalt  Children's Books
# 6                 Drew Daywalt  Children's Books
# 7                Giles Andreae  Children's Books
# 8                   Eric Carle  Children's Books
# 9        Rachel Ren̩e Russell  Children's Books
# 10                  James Dean  Children's Books
# 11                Rod Campbell  Children's Books
# 12                  B.J. Novak  Children's Books
# 13              Alice Schertle  Children's Books
# 14       Emily Winfield Martin  Children's Books
# 15            Shel Silverstein  Children's Books
# 16               DK Publishing  Children's Books
# 17              Sandra Boynton  Children's Books
# 18               Robert Munsch  Children's Books
# 19             Julia Donaldson  Children's Books
# 20                Golden Books  Children's Books
# 21                Rick Riordan  Children's Books
# 22             Bill Martin Jr.  Children's Books
# 23                 Rob Elliott  Children's Books
# 24                  Adam Rubin  Children's Books
# 25         Margaret Wise Brown  Children's Books
# 26              Sandra Boynton  Children's Books
# 27             Bill Martin Jr.  Children's Books
# 28           Leslie Patricelli  Children's Books
# 29                   Dr. Seuss  Children's Books
# ...                        ...               ...
# 13575             Jimmy Fallon  Children's Books
# 13576               Dan Gutman  Children's Books
# 13577         Matt Christopher  Children's Books
# 13578            Scott Ciencin  Children's Books
# 13579              Joan Leotta  Children's Books
# 13580             John Danakas  Children's Books
# 13581              Jake Maddox  Children's Books
# 13582                      NaN  Children's Books
# 13583                      NaN  Children's Books
# 13584                Sam Usher  Children's Books
# 13585  Lorna Schultz Nicholson  Children's Books
# 13586                Jeff Ross  Children's Books
# 13587            Roy MacGregor  Children's Books
# 13588             Anne E. Hill  Children's Books
# 13589         Matt Christopher  Children's Books
# 13590             Cari Meister  Children's Books
# 13591         Matt Christopher  Children's Books
# 13592            Karla Oceanak  Children's Books
# 13593              Terri Woods  Children's Books
# 13594               Ned Miller  Children's Books
# 13595            Julie Mammano  Children's Books
# 13596  Lorna Schultz Nicholson  Children's Books
# 13597            Roy MacGregor  Children's Books
# 13598            Roy MacGregor  Children's Books
# 13599         Patricia Hubbell  Children's Books
# 13600           Sandra Diersch  Children's Books
# 13601             Cari Meister  Children's Books
# 13602          Robert J. Blake  Children's Books
# 13603           Jon M. Fishman  Children's Books
# 13604         Per Henrik Gurth  Children's Books
#
# [13605 rows x 6 columns]

# %% [markdown]
# #### Bringing it together

# %%
# To use to parse dates later on
# from dateutil import parser
# parser.parse(date)

# %%
def scrape_info(book_id):
    # Trick the bot detector?
    sleep(randint(1,3))
    
    # Get the soup of the relevant page
    request = requests.get('https://www.amazon.com/dp/' + book_id)
    status = request.status_code
    
    if(status == 200):
        soup = BeautifulSoup(request.text, 'lxml')

        # Get sales rank and time
        for li in soup.select('#productDetailsTable li'):
            if(li.b.string == 'Amazon Best Sellers Rank:'):
                try:
                    sales_rank = re.findall(u'#([\d,]+)', li.b.nextSibling)[0]  # Format: #1,234,567
                    sales_rank = int(sales_rank.replace(',',''))  # Remove the commas and convert to integer
                except:
                    sales_rank = None
            elif(li.b.string == 'Publisher:'):
                try:
                    date = re.findall(u'\(([^\(\)]*)\)$', li.b.nextSibling)[0]  # Format: (MM YYYY)
                except:
                    date = None

        # Get average review score
        try:
            reviews = soup.select('#histogramTable')[0].text
            reviews = re.findall(u'(\d) star(\d+)%', reviews)

            score = 0
            for pair in reviews:
                score += int(pair[0]) * int(pair[1])/100  # weights are percentages
            score = round(score, 4)
        except:
            score = None
    else:
        sales_rank = date = score = f'Error {request.status_code}'

    return status, book_id, sales_rank, date, score

# %% [markdown]
# Let's do a final test on the example book we used above:

# %%
scraped = scrape_info(book_id)
scraped
# Out:
# (200, '0006476155', 5130272, 'March 2004', 4.29)

# %% [markdown]
# ## Completing the dataset

# %%
books.head()
# Out:
#            ID        Filename  \
# 0   545790352  0545790352.jpg
# 1  1419717014  1419717014.jpg
# 2  1423160916  1423160916.jpg
# 3  1476789886  1476789886.jpg
# 4  1338029991  1338029991.jpg
#
#                                            Image URL  \
# 0  http://ecx.images-amazon.com/images/I/51MIi4p2...
# 1  http://ecx.images-amazon.com/images/I/61YgGsg-...
# 2  http://ecx.images-amazon.com/images/I/611CmvkL...
# 3  http://ecx.images-amazon.com/images/I/51KqU7Dw...
# 4  http://ecx.images-amazon.com/images/I/61kvq74k...
#
#                                                Title         Author  \
# 0  Harry Potter and the Sorcerer's Stone: The Ill...   J.K. Rowling
# 1                   Diary of a Wimpy Kid: Old School    Jeff Kinney
# 2  Magnus Chase and the Gods of Asgard, Book 1: T...   Rick Riordan
# 3           Rush Revere and the Star-Spangled Banner  Rush Limbaugh
# 4                         Harry Potter Coloring Book     Scholastic
#
#            Category
# 0  Children's Books
# 1  Children's Books
# 2  Children's Books
# 3  Children's Books
# 4  Children's Books

# %%
scraped = dataset.head(100).apply(lambda row: scrape_info(row['ID']), axis=1)
scraped
# Out:
# 2636       (3632, October 13, 2015, 4.72)
# 2637    (25151, September 15, 2015, 4.85)
# 2638           (2405, May 19, 2009, 4.72)
# 2639         (4062, March 19, 2008, 4.65)
# 2640       (3986, October 16, 2012, 4.82)
# 2641       (78666, October 6, 2015, 4.72)
# 2642     (27529, September 1, 2015, 4.74)
# 2643      (25807, October 20, 2015, 4.92)
# 2644     (49660, November 10, 2015, 4.61)
# 2645      (16097, December 1, 2015, 4.92)
# 2646    (Error 404, Error 404, Error 404)
# 2647    (Error 404, Error 404, Error 404)
# 2648    (Error 404, Error 404, Error 404)
# 2649    (80905, September 22, 2015, 4.69)
# 2650    (Error 404, Error 404, Error 404)
# 2651          (3005, July 22, 2014, 4.51)
# 2652          (447, March 17, 2014, 4.81)
# 2653      (55551, October 20, 2015, 4.84)
# 2654      (202321, October 6, 2015, 4.91)
# 2655    (Error 404, Error 404, Error 404)
# 2656         (4054, April 18, 2012, 4.66)
# 2657    (Error 404, Error 404, Error 404)
# 2658    (21204, September 22, 2015, 4.64)
# 2659         (674, October 2, 2012, 4.54)
# 2660      (24358, October 20, 2015, 4.79)
# 2661       (1509, January 29, 2013, 4.85)
# 2662                  (22743, 2013, 4.65)
# 2663         (6905, April 11, 2007, 4.34)
# 2664           (95246, May 1, 1997, 4.54)
# 2665     (389646, October 13, 2015, 3.84)
#                       ...
# 2706    (Error 404, Error 404, Error 404)
# 2707          (19969, May 13, 2014, 4.65)
# 2708       (3758, October 15, 2013, 4.82)
# 2709      (350940, October 6, 2015, 4.71)
# 2710       (1674, October 29, 2013, 4.76)
# 2711         (10478, April 7, 2015, 4.42)
# 2712          (50116, May 12, 2015, 4.72)
# 2713    (Error 404, Error 404, Error 404)
# 2714       (6812, October 24, 2008, 4.48)
# 2715     (20774, September 1, 2015, 4.79)
# 2716    (16266, September 11, 2012, 4.32)
# 2717       (61969, October 6, 2015, 4.04)
# 2718          (8215, April 27, 1994, 4.7)
# 2719       (12506, August 18, 2015, 4.75)
# 2720    (Error 503, Error 503, Error 503)
# 2721    (Error 404, Error 404, Error 404)
# 2722     (2631, September 25, 2012, 4.82)
# 2723         (11932, June 16, 2015, 4.83)
# 2724    (Error 404, Error 404, Error 404)
# 2725     (74159, September 9, 2015, 4.46)
# 2726      (130668, October 8, 2013, 4.69)
# 2727    (Error 404, Error 404, Error 404)
# 2728           (47505, May 5, 2015, 4.65)
# 2729     (108625, October 13, 2015, 3.98)
# 2730    (Error 404, Error 404, Error 404)
# 2731    (Error 404, Error 404, Error 404)
# 2732      (69708, October 13, 2015, 4.89)
# 2733    (Error 404, Error 404, Error 404)
# 2734    (Error 404, Error 404, Error 404)
# 2735      (65918, October 27, 2015, 4.78)
# Length: 100, dtype: object

# %% [markdown]
# ### Parallelize It

# %%
from dask import dataframe as dd
from dask.multiprocessing import get
from multiprocessing import cpu_count
nCores = cpu_count()

# %%
test = dd.from_pandas(books.head(12), npartitions=nCores).\
   map_partitions(
      lambda df : df.apply(
         lambda row : scrape_info(row['ID']), axis=1)).\
   compute(get=get)

# %%
test.apply(pd.Series)
# Out:
#              0          1                 2          3
# 0    545790352  Error 404         Error 404  Error 404
# 1   1419717014        572  November 3, 2015        4.8
# 2   1423160916      10711   October 6, 2015        4.6
# 3   1476789886  Error 503         Error 503  Error 503
# 4   1338029991  Error 503         Error 503  Error 503
# 5    399172750  Error 404         Error 404  Error 404
# 6    399255370  Error 404         Error 404  Error 404
# 7    545392551  Error 404         Error 404  Error 404
# 8    399226907  Error 404         Error 404  Error 404
# 9   1481457047       5249  October 20, 2015       4.81
# 10    62304186  Error 404         Error 404  Error 404
# 11  141694737X         71       May 8, 2007       4.79

# %%
with open('yo.csv', 'a') as file:
    dd.from_pandas(books.head(nCores), npartitions=nCores).\
       map_partitions(
          lambda df : df.apply(
             lambda row : scrape_info(row['ID']), axis=1)).\
       compute(get=get).apply(pd.Series).to_csv(file, header=False, index=False)

# %% [markdown]
# ### Scrape data to CSV, download image to folder

# %%
with open('yo.csv', 'a') as file:
    writer = csv.writer(file)
    writer.writerow(['ID', 'Sales Rank', 'Date', 'Review Score'])

# %%
with open('scraped.csv', 'a+') as file:
    reader = csv.reader(file)
    writer = csv.writer(file)
    
    # Look at the last scraped book to continue from the next one in the dataset
    file.seek(0)
    last_scraped = next(reversed(list(reader)))[0]
    
    if(last_scraped == 'ID'):
        # If nothing was scraped yet, start from the beginning
        index = 0
    else:
        # If something was scraped, find the index of the last scraped one and start from the next one
        last_scraped_index = books.index[books['ID'] == last_scraped].tolist()[0]
        index = last_scraped_index + 1
        
    try:
        while(True):
            current_id = books.iloc[index]['ID']
            scraped = scrape_info(current_id)
            
            writer.writerow(scraped[1:])
            file.flush()

            if(scraped[0] == 200):
                download_image(current_id)

            index += 1
    except KeyboardInterrupt:
        pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-0fbc9b446f84> in <module>()
#      24
#      25             if(scraped[0] == 200):
# ---> 26                 download_image(current_id)
#      27
#      28             index += 1
#
# NameError: name 'download_image' is not defined

# %% [markdown]
# Initialize CSV file:

# %%
with open('scraped.csv', 'a') as file:
    writer = csv.writer(file)
    writer.writerow(['ID', 'Sales Rank', 'Date', 'Review Score'])

# %% [markdown]
# Scrape and append to CSV file and download the image:

# %%
with open('scraped.csv', 'a+') as file:
    reader = csv.reader(file)
    writer = csv.writer(file)
    
    try:
        # Look at the last scraped book to continue from the next one in the dataset
        file.seek(0)
        last_scraped = next(reversed(list(reader)))[0]
        last_scraped_index = books.index[books['ID'] == last_scraped].tolist()[0]
        index = last_scraped_index + 1
    except:
        # If there is nothing scraped, start from the beginning
        index = 0
    finally:
        try:
            while(True):
                current_id = books.iloc[index]['ID']
                writer.writerow(scrape_info(current_id))
                file.flush()
                
#                 download_image(current_id)
                
                index += 1
        except KeyboardInterrupt:
            pass

# %% [markdown]
# # JOIN

# %%
header_names = ['ID', 'Filename', 'Image URL', 'Title', 'Author', 'Category ID', 'Category']
old = pd.read_csv('book32-listing.csv', encoding='latin1', header=None, names=header_names)
old.head()
# Out:
#            ID        Filename  \
# 0   761183272  0761183272.jpg
# 1  1623439671  1623439671.jpg
# 2  B00O80WC6I  B00O80WC6I.jpg
# 3   761182187  0761182187.jpg
# 4  1578052084  1578052084.jpg
#
#                                            Image URL  \
# 0  http://ecx.images-amazon.com/images/I/61Y5cOdH...
# 1  http://ecx.images-amazon.com/images/I/61t-hrSw...
# 2  http://ecx.images-amazon.com/images/I/41X-KQqs...
# 3  http://ecx.images-amazon.com/images/I/61j-4gxJ...
# 4  http://ecx.images-amazon.com/images/I/51Ry4Tsq...
#
#                                                Title              Author  \
# 0                    Mom's Family Wall Calendar 2016      Sandra Boynton
# 1                    Doug the Pug 2016 Wall Calendar        Doug the Pug
# 2  Moleskine 2016 Weekly Notebook, 12M, Large, Bl...           Moleskine
# 3            365 Cats Color Page-A-Day Calendar 2016  Workman Publishing
# 4               Sierra Club Engagement Calendar 2016         Sierra Club
#
#    Category ID   Category
# 0            3  Calendars
# 1            3  Calendars
# 2            3  Calendars
# 3            3  Calendars
# 4            3  Calendars

# %%
new = pd.read_csv('scraped.csv')
new = new[new['Sales Rank'] != 'Error 404']
new = new[new['Sales Rank'] != 'Error 503']
new.head()
# Out:
#            ID Sales Rank               Date Review Score
# 1  1419717014        514   November 3, 2015          4.8
# 2  1423160916      11039    October 6, 2015          4.6
# 3  1476789886       5917   October 27, 2015          4.9
# 4  1338029991        217  November 10, 2015         4.61
# 9  1481457047       5267   October 20, 2015         4.81

# %%
old = old.set_index('ID')
new = new.set_index('ID')

# %%
new.shape
# Out:
# (193, 4)

# %%
new.join(old).iloc[0]['Image URL']
# Out:
# 'http://ecx.images-amazon.com/images/I/61YgGsg-k-L.jpg'

# %%
df = new.join(old)
df.head()
# Out:
#            Sales Rank               Date Review Score        Filename  \
# ID
# 1419717014        514   November 3, 2015          4.8  1419717014.jpg
# 1423160916      11039    October 6, 2015          4.6  1423160916.jpg
# 1476789886       5917   October 27, 2015          4.9  1476789886.jpg
# 1338029991        217  November 10, 2015         4.61  1338029991.jpg
# 1481457047       5267   October 20, 2015         4.81  1481457047.jpg
#
#                                                     Image URL  \
# ID
# 1419717014  http://ecx.images-amazon.com/images/I/61YgGsg-...
# 1423160916  http://ecx.images-amazon.com/images/I/611CmvkL...
# 1476789886  http://ecx.images-amazon.com/images/I/51KqU7Dw...
# 1338029991  http://ecx.images-amazon.com/images/I/61kvq74k...
# 1481457047  http://ecx.images-amazon.com/images/I/61GfN%2B...
#
#                                                         Title  \
# ID
# 1419717014                   Diary of a Wimpy Kid: Old School
# 1423160916  Magnus Chase and the Gods of Asgard, Book 1: T...
# 1476789886           Rush Revere and the Star-Spangled Banner
# 1338029991                         Harry Potter Coloring Book
# 1481457047  Dork Diaries 10: Tales from a Not-So-Perfect P...
#
#                            Author  Category ID          Category
# ID
# 1419717014            Jeff Kinney            4  Children's Books
# 1423160916           Rick Riordan            4  Children's Books
# 1476789886          Rush Limbaugh            4  Children's Books
# 1338029991             Scholastic            4  Children's Books
# 1481457047  Rachel Ren̩e Russell            4  Children's Books

# %%
IMAGE_PATH = 'images/'

# %%
download_image('1419717014.jpg', 'http://ecx.images-amazon.com/images/I/61YgGsg-k-L.jpg')

# %%
def download_image(book_id):
    filename, url = old.loc[book_id][['Filename', 'Image URL']]
    if not os.path.isfile(IMAGE_PATH + filename):
            downloaded_img = urllib.request.urlopen(url)
            f = open(IMAGE_PATH + filename, mode='wb')
            f.write(downloaded_img.read())
            downloaded_img.close()
            f.close()

# %%
df.apply(lambda row: download_image(row['Filename'], row['Image URL']), axis=1);
